# %%
from wwo_hist import retrieve_hist_data
frequency = 1
start_date = '01-JAN-2009'
end_date = '19-JUN-2020'
api_key = "166b5591f9ff4f2988e212125201806"
location_list = ['Seoul','Sydney','Seattle','Washington DC','california','Dubai','beijing','taipei']
#done: 'madrid','Barcelona','Osaka','Amsterdam','Rome','Mumbai','Jakarta','Bangkok','Singapore','HongKong','New-York','Tokyo','London','Paris','Chicago','Boston','Toronto','Melbourne','Berlin',
hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Boston
#
#
# Currently retrieving data for Boston: from 2009-01-01 to 2009-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.605420
# Currently retrieving data for Boston: from 2009-02-01 to 2009-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:08.389622
# Currently retrieving data for Boston: from 2009-03-01 to 2009-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.115657
# Currently retrieving data for Boston: from 2009-04-01 to 2009-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:15.808393
# Currently retrieving data for Boston: from 2009-05-01 to 2009-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:19.722942
# Currently retrieving data for Boston: from 2009-06-01 to 2009-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:23.341016
# Currently retrieving data for Boston: from 2009-07-01 to 2009-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:27.019177
# Currently retrieving data for Boston: from 2009-08-01 to 2009-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:31.086692
# ...
